# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
test_df = pd.read_csv('./SmartFall Testing.csv')
n = 40
number = 1

plt.ylabel("Accelerometer data")
plt.plot(test_df[' ms_accelerometer_x'][0 : 200], label="acc_x")
plt.plot(test_df[' ms_accelerometer_y'][0 : 200], label="acc_x")
plt.plot(test_df[' ms_accelerometer_z'][0 : 200], label="acc_x")
plt.legend()
